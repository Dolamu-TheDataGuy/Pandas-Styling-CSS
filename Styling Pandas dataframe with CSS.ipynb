# %% [markdown]
# ### Styling Pandas DataFrame

# %% [markdown]
# Is the monotonous Pandas DataFrame dull to you?, we can actually light our dataframes up by styling them with the popular Cascading Sheet Style known as CSS. I would be utilizing the current Premier league seasons table I scraped from <a href = 'skysport.com'>Skysport.</a>

# %%
import pandas as pd
import numpy as np

# %%
tab = pd.read_csv('pl_GW3.csv')
tab
# Out:
#     Position                     Teams  Games_Played  Games_Won  Games_Drawn  \
# 0          1         Tottenham Hotspur             3          3            0
# 1          2           West Ham United             3          2            1
# 2          3         Manchester United             3          2            1
# 3          4                   Chelsea             3          2            1
# 4          5                 Liverpool             3          2            1
# 5          6                   Everton             3          2            1
# 6          7           Manchester City             3          2            0
# 7          8  Brighton and Hove Albion             3          2            0
# 8          9            Leicester City             3          2            0
# 9         10                 Brentford             3          1            2
# 10        11               Aston Villa             3          1            1
# 11        12                   Watford             3          1            0
# 12        13               Southampton             3          0            2
# 13        14            Crystal Palace             3          0            2
# 14        15              Leeds United             3          0            2
# 15        16                   Burnley             3          0            1
# 16        17          Newcastle United             3          0            1
# 17        18   Wolverhampton Wanderers             3          0            0
# 18        19              Norwich City             3          0            0
# 19        20                   Arsenal             3          0            0
#
#     Games_Lost  GF  GA  GD  Points
# 0            0   3   0   3       9
# 1            0  10   5   5       7
# 2            0   7   2   5       7
# 3            0   6   1   5       7
# 4            0   6   1   5       7
# 5            0   7   3   4       7
# 6            1  10   1   9       6
# 7            1   4   3   1       6
# 8            1   4   5  -1       6
# 9            0   3   1   2       5
# 10           1   5   4   1       4
# 11           2   3   5  -2       3
# 12           1   4   6  -2       2
# 13           1   2   5  -3       2
# 14           1   4   8  -4       2
# 15           2   2   5  -3       1
# 16           2   4   8  -4       1
# 17           3   0   3  -3       0
# 18           3   1  10  -9       0
# 19           3   0   9  -9       0

# %% [markdown]
# ### Style pandas table with CSS

# %%
tab.style.set_table_styles(
[{'selector': 'th',
 'props': [('background','#00bfff'),
         ('color', 'white'),
         ('font-family', 'century gothic')]},
 
 {'selector': 'td',
 'props': [('font-family','verdana')]},
 
 {'selector': 'tr:nth-of-type(odd)',
 'props':[('background','#00FF00')]},
 
 {'selector':'tr:nth-of-type(even)',
 'props':[('background','white')]}
  
]
).hide_index()
# Out:
# <style  type="text/css" >
#     #T_271f3_ th {
#           background: #00bfff;
#           color: white;
#           font-family: century gothic;
#     }    #T_271f3_ td {
#           font-family: verdana;
#     }    #T_271f3_ tr:nth-of-type(odd) {
#           background: #00FF00;
#     }    #T_271f3_ tr:nth-of-type(even) {
#           background: white;
#     }</style><table id="T_271f3_" ><thead>    <tr>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Games_Played</th>        <th class="col_heading level0 col3" >Games_Won</th>        <th class="col_heading level0 col4" >Games_Drawn</th>        <th class="col_heading level0 col5" >Games_Lost</th>        <th class="col_heading level0 col6" >GF</th>        <th class="col_heading level0 col7" >GA</th>        <th class="col_heading level0 col8" >GD</th>        <th class="col_heading level0 col9" >Points</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_271f3_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_271f3_row0_col1" class="data row0 col1" >Tottenham Hotspur</td>
#                         <td id="T_271f3_row0_col2" class="data row0 col2" >3</td>
#                         <td id="T_271f3_row0_col3" class="data row0 col3" >3</td>
#                         <td id="T_271f3_row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_271f3_row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_271f3_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_271f3_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_271f3_row0_col8" class="data row0 col8" >3</td>
#                         <td id="T_271f3_row0_col9" class="data row0 col9" >9</td>
#             </tr>
#             <tr>
#                                 <td id="T_271f3_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_271f3_row1_col1" class="data row1 col1" >West Ham United</td>
#                         <td id="T_271f3_row1_col2" class="data row1 col2" >3</td>
#                         <td id="T_271f3_row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_271f3_row1_col4" class="data row1 col4" >1</td>
#                         <td id="T_271f3_row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_271f3_row1_col6" class="data row1 col6" >10</td>
#                         <td id="T_271f3_row1_col7" class="data row1 col7" >5</td>
#                         <td id="T_271f3_row1_col8" class="data row1 col8" >5</td>
#                         <td id="T_271f3_row1_col9" class="data row1 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_271f3_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_271f3_row2_col1" class="data row2 col1" >Manchester United</td>
#                         <td id="T_271f3_row2_col2" class="data row2 col2" >3</td>
#                         <td id="T_271f3_row2_col3" class="data row2 col3" >2</td>
#                         <td id="T_271f3_row2_col4" class="data row2 col4" >1</td>
#                         <td id="T_271f3_row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_271f3_row2_col6" class="data row2 col6" >7</td>
#                         <td id="T_271f3_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_271f3_row2_col8" class="data row2 col8" >5</td>
#                         <td id="T_271f3_row2_col9" class="data row2 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_271f3_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_271f3_row3_col1" class="data row3 col1" >Chelsea</td>
#                         <td id="T_271f3_row3_col2" class="data row3 col2" >3</td>
#                         <td id="T_271f3_row3_col3" class="data row3 col3" >2</td>
#                         <td id="T_271f3_row3_col4" class="data row3 col4" >1</td>
#                         <td id="T_271f3_row3_col5" class="data row3 col5" >0</td>
#                         <td id="T_271f3_row3_col6" class="data row3 col6" >6</td>
#                         <td id="T_271f3_row3_col7" class="data row3 col7" >1</td>
#                         <td id="T_271f3_row3_col8" class="data row3 col8" >5</td>
#                         <td id="T_271f3_row3_col9" class="data row3 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_271f3_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_271f3_row4_col1" class="data row4 col1" >Liverpool</td>
#                         <td id="T_271f3_row4_col2" class="data row4 col2" >3</td>
#                         <td id="T_271f3_row4_col3" class="data row4 col3" >2</td>
#                         <td id="T_271f3_row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_271f3_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_271f3_row4_col6" class="data row4 col6" >6</td>
#                         <td id="T_271f3_row4_col7" class="data row4 col7" >1</td>
#                         <td id="T_271f3_row4_col8" class="data row4 col8" >5</td>
#                         <td id="T_271f3_row4_col9" class="data row4 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_271f3_row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_271f3_row5_col1" class="data row5 col1" >Everton</td>
#                         <td id="T_271f3_row5_col2" class="data row5 col2" >3</td>
#                         <td id="T_271f3_row5_col3" class="data row5 col3" >2</td>
#                         <td id="T_271f3_row5_col4" class="data row5 col4" >1</td>
#                         <td id="T_271f3_row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_271f3_row5_col6" class="data row5 col6" >7</td>
#                         <td id="T_271f3_row5_col7" class="data row5 col7" >3</td>
#                         <td id="T_271f3_row5_col8" class="data row5 col8" >4</td>
#                         <td id="T_271f3_row5_col9" class="data row5 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_271f3_row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_271f3_row6_col1" class="data row6 col1" >Manchester City</td>
#                         <td id="T_271f3_row6_col2" class="data row6 col2" >3</td>
#                         <td id="T_271f3_row6_col3" class="data row6 col3" >2</td>
#                         <td id="T_271f3_row6_col4" class="data row6 col4" >0</td>
#                         <td id="T_271f3_row6_col5" class="data row6 col5" >1</td>
#                         <td id="T_271f3_row6_col6" class="data row6 col6" >10</td>
#                         <td id="T_271f3_row6_col7" class="data row6 col7" >1</td>
#                         <td id="T_271f3_row6_col8" class="data row6 col8" >9</td>
#                         <td id="T_271f3_row6_col9" class="data row6 col9" >6</td>
#             </tr>
#             <tr>
#                                 <td id="T_271f3_row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_271f3_row7_col1" class="data row7 col1" >Brighton and Hove Albion</td>
#                         <td id="T_271f3_row7_col2" class="data row7 col2" >3</td>
#                         <td id="T_271f3_row7_col3" class="data row7 col3" >2</td>
#                         <td id="T_271f3_row7_col4" class="data row7 col4" >0</td>
#                         <td id="T_271f3_row7_col5" class="data row7 col5" >1</td>
#                         <td id="T_271f3_row7_col6" class="data row7 col6" >4</td>
#                         <td id="T_271f3_row7_col7" class="data row7 col7" >3</td>
#                         <td id="T_271f3_row7_col8" class="data row7 col8" >1</td>
#                         <td id="T_271f3_row7_col9" class="data row7 col9" >6</td>
#             </tr>

# %% [markdown]
# The table looks more beautiful and friendly this way.

# %% [markdown]
# ### Adding Purple highlight upon hover

# %%
tab.style.set_table_styles(
[{'selector': 'th',
 'props': [('background','#00bfff'),
         ('color', 'white'),
         ('font-family', 'century gothic')]},
 
 {'selector': 'td',
 'props': [('font-family','verdana')]},
 
 {'selector': 'tr:nth-of-type(odd)',
 'props':[('background','#00FF00')]},
 
 {'selector':'tr:nth-of-type(even)',
 'props':[('background','white')]},
 
 {'selector': 'tr:hover',
 'props': [('background-color', 'purple')]}
 
]
).hide_index()
# Out:
# <style  type="text/css" >
#     #T_29272_ th {
#           background: #00bfff;
#           color: white;
#           font-family: century gothic;
#     }    #T_29272_ td {
#           font-family: verdana;
#     }    #T_29272_ tr:nth-of-type(odd) {
#           background: #00FF00;
#     }    #T_29272_ tr:nth-of-type(even) {
#           background: white;
#     }    #T_29272_ tr:hover {
#           background-color: purple;
#     }</style><table id="T_29272_" ><thead>    <tr>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Games_Played</th>        <th class="col_heading level0 col3" >Games_Won</th>        <th class="col_heading level0 col4" >Games_Drawn</th>        <th class="col_heading level0 col5" >Games_Lost</th>        <th class="col_heading level0 col6" >GF</th>        <th class="col_heading level0 col7" >GA</th>        <th class="col_heading level0 col8" >GD</th>        <th class="col_heading level0 col9" >Points</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_29272_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_29272_row0_col1" class="data row0 col1" >Tottenham Hotspur</td>
#                         <td id="T_29272_row0_col2" class="data row0 col2" >3</td>
#                         <td id="T_29272_row0_col3" class="data row0 col3" >3</td>
#                         <td id="T_29272_row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_29272_row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_29272_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_29272_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_29272_row0_col8" class="data row0 col8" >3</td>
#                         <td id="T_29272_row0_col9" class="data row0 col9" >9</td>
#             </tr>
#             <tr>
#                                 <td id="T_29272_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_29272_row1_col1" class="data row1 col1" >West Ham United</td>
#                         <td id="T_29272_row1_col2" class="data row1 col2" >3</td>
#                         <td id="T_29272_row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_29272_row1_col4" class="data row1 col4" >1</td>
#                         <td id="T_29272_row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_29272_row1_col6" class="data row1 col6" >10</td>
#                         <td id="T_29272_row1_col7" class="data row1 col7" >5</td>
#                         <td id="T_29272_row1_col8" class="data row1 col8" >5</td>
#                         <td id="T_29272_row1_col9" class="data row1 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_29272_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_29272_row2_col1" class="data row2 col1" >Manchester United</td>
#                         <td id="T_29272_row2_col2" class="data row2 col2" >3</td>
#                         <td id="T_29272_row2_col3" class="data row2 col3" >2</td>
#                         <td id="T_29272_row2_col4" class="data row2 col4" >1</td>
#                         <td id="T_29272_row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_29272_row2_col6" class="data row2 col6" >7</td>
#                         <td id="T_29272_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_29272_row2_col8" class="data row2 col8" >5</td>
#                         <td id="T_29272_row2_col9" class="data row2 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_29272_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_29272_row3_col1" class="data row3 col1" >Chelsea</td>
#                         <td id="T_29272_row3_col2" class="data row3 col2" >3</td>
#                         <td id="T_29272_row3_col3" class="data row3 col3" >2</td>
#                         <td id="T_29272_row3_col4" class="data row3 col4" >1</td>
#                         <td id="T_29272_row3_col5" class="data row3 col5" >0</td>
#                         <td id="T_29272_row3_col6" class="data row3 col6" >6</td>
#                         <td id="T_29272_row3_col7" class="data row3 col7" >1</td>
#                         <td id="T_29272_row3_col8" class="data row3 col8" >5</td>
#                         <td id="T_29272_row3_col9" class="data row3 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_29272_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_29272_row4_col1" class="data row4 col1" >Liverpool</td>
#                         <td id="T_29272_row4_col2" class="data row4 col2" >3</td>
#                         <td id="T_29272_row4_col3" class="data row4 col3" >2</td>
#                         <td id="T_29272_row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_29272_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_29272_row4_col6" class="data row4 col6" >6</td>
#                         <td id="T_29272_row4_col7" class="data row4 col7" >1</td>
#                         <td id="T_29272_row4_col8" class="data row4 col8" >5</td>
#                         <td id="T_29272_row4_col9" class="data row4 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_29272_row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_29272_row5_col1" class="data row5 col1" >Everton</td>
#                         <td id="T_29272_row5_col2" class="data row5 col2" >3</td>
#                         <td id="T_29272_row5_col3" class="data row5 col3" >2</td>
#                         <td id="T_29272_row5_col4" class="data row5 col4" >1</td>
#                         <td id="T_29272_row5_col5" class="data row5 col5" >0</td>
#                         <td id="T_29272_row5_col6" class="data row5 col6" >7</td>
#                         <td id="T_29272_row5_col7" class="data row5 col7" >3</td>
#                         <td id="T_29272_row5_col8" class="data row5 col8" >4</td>
#                         <td id="T_29272_row5_col9" class="data row5 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_29272_row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_29272_row6_col1" class="data row6 col1" >Manchester City</td>
#                         <td id="T_29272_row6_col2" class="data row6 col2" >3</td>
#                         <td id="T_29272_row6_col3" class="data row6 col3" >2</td>
#                         <td id="T_29272_row6_col4" class="data row6 col4" >0</td>
#                         <td id="T_29272_row6_col5" class="data row6 col5" >1</td>
#                         <td id="T_29272_row6_col6" class="data row6 col6" >10</td>
#                         <td id="T_29272_row6_col7" class="data row6 col7" >1</td>
#                         <td id="T_29272_row6_col8" class="data row6 col8" >9</td>
#                         <td id="T_29272_row6_col9" class="data row6 col9" >6</td>
#             </tr>
#             <tr>
#                                 <td id="T_29272_row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_29272_row7_col1" class="data row7 col1" >Brighton and Hove Albion</td>
#                         <td id="T_29272_row7_col2" class="data row7 col2" >3</td>
#                         <td id="T_29272_row7_col3" class="data row7 col3" >2</td>
#                         <td id="T_29272_row7_col4" class="data row7 col4" >0</td>
#                         <td id="T_29272_row7_col5" class="data row7 col5" >1</td>
#                         <td id="T_29272_row7_col6" class="data row7 col6" >4</td>
#                         <td id="T_29272_row7_col7" class="data row7 col7" >3</td>
#                         <td id="T_29272_row7_col8" class="data row7 col8" >1</td>
#                         <td id="T_29272_r

# %% [markdown]
# so when we hover on our dataframe, the concentrated row becomes purple in color.

# %% [markdown]
# ### Conditional Coloring

# %% [markdown]
# We can actually carry out conditional formatting on our dataframes similar to how excel, This is could be very helpful in visualizing important details on straight from your dataframe. the process can be done by either writing a function and using the `applymap` function to run the apply the function to your dataframe or using the methods present on the Pandas Styling API. We would use the 2 methods in this exercise. When using raw functions, we can use one of the following to help reach our goal:
#
# - `Styler.applymap(func)` for element-wise styles.
#
#
#
# - `Styler.applymap(func, axis = 0)` for column-wise styles.
#
#
#
# - `Styler.applymap(func, axis = 1)` for row-wise styles.
#
#
#
# - `Styler.apply(func, axis=None)` for tablewise styles

# %%
def color_format(case):
    if case >= 7:
        color = '#086613'
    elif case < 7 and case >=1:
        color = '#1FD9DC'
    else:
        color = '#EF0C21 '
    return 'color: %s' % color

a = tab[['GA','Points']].style.applymap(color_format)
a
# Out:
# <style  type="text/css" >
# #T_99a08_row0_col0,#T_99a08_row17_col1,#T_99a08_row18_col1,#T_99a08_row19_col1{
#             color:  #EF0C21 ;
#         }#T_99a08_row0_col1,#T_99a08_row1_col1,#T_99a08_row2_col1,#T_99a08_row3_col1,#T_99a08_row4_col1,#T_99a08_row5_col1,#T_99a08_row14_col0,#T_99a08_row16_col0,#T_99a08_row18_col0,#T_99a08_row19_col0{
#             color:  #086613;
#         }#T_99a08_row1_col0,#T_99a08_row2_col0,#T_99a08_row3_col0,#T_99a08_row4_col0,#T_99a08_row5_col0,#T_99a08_row6_col0,#T_99a08_row6_col1,#T_99a08_row7_col0,#T_99a08_row7_col1,#T_99a08_row8_col0,#T_99a08_row8_col1,#T_99a08_row9_col0,#T_99a08_row9_col1,#T_99a08_row10_col0,#T_99a08_row10_col1,#T_99a08_row11_col0,#T_99a08_row11_col1,#T_99a08_row12_col0,#T_99a08_row12_col1,#T_99a08_row13_col0,#T_99a08_row13_col1,#T_99a08_row14_col1,#T_99a08_row15_col0,#T_99a08_row15_col1,#T_99a08_row16_col1,#T_99a08_row17_col0{
#             color:  #1FD9DC;
#         }</style><table id="T_99a08_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >GA</th>        <th class="col_heading level0 col1" >Points</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_99a08_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_99a08_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_99a08_row0_col1" class="data row0 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_99a08_row1_col0" class="data row1 col0" >5</td>
#                         <td id="T_99a08_row1_col1" class="data row1 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_99a08_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_99a08_row2_col1" class="data row2 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_99a08_row3_col0" class="data row3 col0" >1</td>
#                         <td id="T_99a08_row3_col1" class="data row3 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_99a08_row4_col0" class="data row4 col0" >1</td>
#                         <td id="T_99a08_row4_col1" class="data row4 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_99a08_row5_col0" class="data row5 col0" >3</td>
#                         <td id="T_99a08_row5_col1" class="data row5 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_99a08_row6_col0" class="data row6 col0" >1</td>
#                         <td id="T_99a08_row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_99a08_row7_col0" class="data row7 col0" >3</td>
#                         <td id="T_99a08_row7_col1" class="data row7 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_99a08_row8_col0" class="data row8 col0" >5</td>
#                         <td id="T_99a08_row8_col1" class="data row8 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_99a08_row9_col0" class="data row9 col0" >1</td>
#                         <td id="T_99a08_row9_col1" class="data row9 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_99a08_row10_col0" class="data row10 col0" >4</td>
#                         <td id="T_99a08_row10_col1" class="data row10 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_99a08_row11_col0" class="data row11 col0" >5</td>
#                         <td id="T_99a08_row11_col1" class="data row11 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_99a08_row12_col0" class="data row12 col0" >6</td>
#                         <td id="T_99a08_row12_col1" class="data row12 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_99a08_row13_col0" class="data row13 col0" >5</td>
#                         <td id="T_99a08_row13_col1" class="data row13 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_99a08_row14_col0" class="data row14 col0" >8</td>
#                         <td id="T_99a08_row14_col1" class="data row14 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_99a08_row15_col0" class="data row15 col0" >5</td>
#                         <td id="T_99a08_row15_col1" class="data row15 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_99a08_row16_col0" class="data row16 col0" >8</td>
#                         <td id="T_99a08_row16_col1" class="data row16 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_99a08_row17_col0" class="data row17 col0" >3</td>
#                         <td id="T_99a08_row17_col1" class="data row17 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_99a08_row18_col0" class="data row18 col0" >10</td>
#                         <td id="T_99a08_row18_col1" class="data row18 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_99a08_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_99a08_row19_col0" class="data row19 col0" >9</td>
#                         <td id="T_99a08_row19_col1" class="data row19 col1" >0</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Pandas Styling API
#
# There is a styling style attributed to the python pandas library that enables you manipulate your dataframe visually,this operation also uses the Cascade Styling Sheet (CSS). We are going to be practicalizing this with the `style_format()` method.

# %%
tab.head(10)
# Out:
#    Position                     Teams  Games_Played  Games_Won  Games_Drawn  \
# 0         1         Tottenham Hotspur             3          3            0
# 1         2           West Ham United             3          2            1
# 2         3         Manchester United             3          2            1
# 3         4                   Chelsea             3          2            1
# 4         5                 Liverpool             3          2            1
# 5         6                   Everton             3          2            1
# 6         7           Manchester City             3          2            0
# 7         8  Brighton and Hove Albion             3          2            0
# 8         9            Leicester City             3          2            0
# 9        10                 Brentford             3          1            2
#
#    Games_Lost  GF  GA  GD  Points
# 0           0   3   0   3       9
# 1           0  10   5   5       7
# 2           0   7   2   5       7
# 3           0   6   1   5       7
# 4           0   6   1   5       7
# 5           0   7   3   4       7
# 6           1  10   1   9       6
# 7           1   4   3   1       6
# 8           1   4   5  -1       6
# 9           0   3   1   2       5

# %% [markdown]
# ### Using `style.format()`

# %% [markdown]
# We are going to use the `style.format()` syntax where can format values in our dataframe, The code is shown below:

# %%
tab.head(15).style.format({"Games_Played": "{:20,.0f}", 
                          "Games_Won": "{:20,.1f}", 
                          "Games_Drawn": "{:20,.1f}",
                          "Games_Lost": "{:20,.2f}",
                          'GD':"{:20,.1f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_4e464_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Games_Played</th>        <th class="col_heading level0 col3" >Games_Won</th>        <th class="col_heading level0 col4" >Games_Drawn</th>        <th class="col_heading level0 col5" >Games_Lost</th>        <th class="col_heading level0 col6" >GF</th>        <th class="col_heading level0 col7" >GA</th>        <th class="col_heading level0 col8" >GD</th>        <th class="col_heading level0 col9" >Points</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4e464_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4e464_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_4e464_row0_col1" class="data row0 col1" >Tottenham Hotspur</td>
#                         <td id="T_4e464_row0_col2" class="data row0 col2" >                   3</td>
#                         <td id="T_4e464_row0_col3" class="data row0 col3" >                 3.0</td>
#                         <td id="T_4e464_row0_col4" class="data row0 col4" >                 0.0</td>
#                         <td id="T_4e464_row0_col5" class="data row0 col5" >                0.00</td>
#                         <td id="T_4e464_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_4e464_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_4e464_row0_col8" class="data row0 col8" >                 3.0</td>
#                         <td id="T_4e464_row0_col9" class="data row0 col9" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_4e464_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4e464_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_4e464_row1_col1" class="data row1 col1" >West Ham United</td>
#                         <td id="T_4e464_row1_col2" class="data row1 col2" >                   3</td>
#                         <td id="T_4e464_row1_col3" class="data row1 col3" >                 2.0</td>
#                         <td id="T_4e464_row1_col4" class="data row1 col4" >                 1.0</td>
#                         <td id="T_4e464_row1_col5" class="data row1 col5" >                0.00</td>
#                         <td id="T_4e464_row1_col6" class="data row1 col6" >10</td>
#                         <td id="T_4e464_row1_col7" class="data row1 col7" >5</td>
#                         <td id="T_4e464_row1_col8" class="data row1 col8" >                 5.0</td>
#                         <td id="T_4e464_row1_col9" class="data row1 col9" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_4e464_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4e464_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_4e464_row2_col1" class="data row2 col1" >Manchester United</td>
#                         <td id="T_4e464_row2_col2" class="data row2 col2" >                   3</td>
#                         <td id="T_4e464_row2_col3" class="data row2 col3" >                 2.0</td>
#                         <td id="T_4e464_row2_col4" class="data row2 col4" >                 1.0</td>
#                         <td id="T_4e464_row2_col5" class="data row2 col5" >                0.00</td>
#                         <td id="T_4e464_row2_col6" class="data row2 col6" >7</td>
#                         <td id="T_4e464_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_4e464_row2_col8" class="data row2 col8" >                 5.0</td>
#                         <td id="T_4e464_row2_col9" class="data row2 col9" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_4e464_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4e464_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_4e464_row3_col1" class="data row3 col1" >Chelsea</td>
#                         <td id="T_4e464_row3_col2" class="data row3 col2" >                   3</td>
#                         <td id="T_4e464_row3_col3" class="data row3 col3" >                 2.0</td>
#                         <td id="T_4e464_row3_col4" class="data row3 col4" >                 1.0</td>
#                         <td id="T_4e464_row3_col5" class="data row3 col5" >                0.00</td>
#                         <td id="T_4e464_row3_col6" class="data row3 col6" >6</td>
#                         <td id="T_4e464_row3_col7" class="data row3 col7" >1</td>
#                         <td id="T_4e464_row3_col8" class="data row3 col8" >                 5.0</td>
#                         <td id="T_4e464_row3_col9" class="data row3 col9" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_4e464_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4e464_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_4e464_row4_col1" class="data row4 col1" >Liverpool</td>
#                         <td id="T_4e464_row4_col2" class="data row4 col2" >                   3</td>
#                         <td id="T_4e464_row4_col3" class="data row4 col3" >                 2.0</td>
#                         <td id="T_4e464_row4_col4" class="data row4 col4" >                 1.0</td>
#                         <td id="T_4e464_row4_col5" class="data row4 col5" >                0.00</td>
#                         <td id="T_4e464_row4_col6" class="data row4 col6" >6</td>
#                         <td id="T_4e464_row4_col7" class="data row4 col7" >1</td>
#                         <td id="T_4e464_row4_col8" class="data row4 col8" >                 5.0</td>
#                         <td id="T_4e464_row4_col9" class="data row4 col9" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_4e464_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4e464_row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_4e464_row5_col1" class="data row5 col1" >Everton</td>
#                         <td id="T_4e464_row5_col2" class="data row5 col2" >                   3</td>
#                         <td id="T_4e464_row5_col3" class="data row5 col3" >                 2.0</td>
#                         <td id="T_4e464_row5_col4" class="data row5 col4" >                 1.0</td>
#                         <td id="T_4e464_row5_col5" class="data row5 col5" >                0.00</td>
#                         <td id="T_4e464_row5_col6" class="data row5 col6" >7</td>
#                         <td id="T_4e464_row5_col7" class="data row5 col7" >3</td>
#                         <td id="T_4e464_row5_col8" class="data row5 col8" >                 4.0</td>
#                         <td id="T_4e464_row5_col9" class="data row5 col9" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_4e464_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4e464_row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_4e464_row6_col1" class="data row6 col1" >Manchester City</td>
#                         <td id="T_4e464_row6_col2" class="data row6 col2" >                   3</td>
#                         <td id="T_4e464_row6_col3" class="data row6 col3" >                 2.0</td>
#                         <td id="T_4e464_row6_col4" class="data row6 col4" >                 0.0</td>
#                         <td id="T_4e464_row6_col5" class="data row6 col5" >                1.00</td>
#                         <td id="T_4e464_row6_col6" class="data row6 col6" >10</td>
#                         <td id="T_4e464_row6_col7" class="data row6 col7" >1</td>
#                         <td id="T_4e464_row6_col8" class="data row6 col8" >                 9.0</td>

# %% [markdown]
# Previously we only formatted our Numerical features, we can also format the categorical features also by running another seperate format syntax as shown below and using the lambda function to write our anonymous function.

# %%
tab.head(15).style.format({"Games_Played": "{:20,.0f}", 
                          "Games_Won": "{:20,.1f}", 
                          "Games_Drawn": "{:20,.1f}",
                          "Games_Lost": "{:20,.2f}",
                          'GD':"{:20,.1f}"})\
                   .format({'Teams':lambda x : x.capitalize()}).hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_c9143_" ><thead>    <tr>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Games_Played</th>        <th class="col_heading level0 col3" >Games_Won</th>        <th class="col_heading level0 col4" >Games_Drawn</th>        <th class="col_heading level0 col5" >Games_Lost</th>        <th class="col_heading level0 col6" >GF</th>        <th class="col_heading level0 col7" >GA</th>        <th class="col_heading level0 col8" >GD</th>        <th class="col_heading level0 col9" >Points</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_c9143_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_c9143_row0_col1" class="data row0 col1" >Tottenham hotspur</td>
#                         <td id="T_c9143_row0_col2" class="data row0 col2" >                   3</td>
#                         <td id="T_c9143_row0_col3" class="data row0 col3" >                 3.0</td>
#                         <td id="T_c9143_row0_col4" class="data row0 col4" >                 0.0</td>
#                         <td id="T_c9143_row0_col5" class="data row0 col5" >                0.00</td>
#                         <td id="T_c9143_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_c9143_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_c9143_row0_col8" class="data row0 col8" >                 3.0</td>
#                         <td id="T_c9143_row0_col9" class="data row0 col9" >9</td>
#             </tr>
#             <tr>
#                                 <td id="T_c9143_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_c9143_row1_col1" class="data row1 col1" >West ham united</td>
#                         <td id="T_c9143_row1_col2" class="data row1 col2" >                   3</td>
#                         <td id="T_c9143_row1_col3" class="data row1 col3" >                 2.0</td>
#                         <td id="T_c9143_row1_col4" class="data row1 col4" >                 1.0</td>
#                         <td id="T_c9143_row1_col5" class="data row1 col5" >                0.00</td>
#                         <td id="T_c9143_row1_col6" class="data row1 col6" >10</td>
#                         <td id="T_c9143_row1_col7" class="data row1 col7" >5</td>
#                         <td id="T_c9143_row1_col8" class="data row1 col8" >                 5.0</td>
#                         <td id="T_c9143_row1_col9" class="data row1 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_c9143_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_c9143_row2_col1" class="data row2 col1" >Manchester united</td>
#                         <td id="T_c9143_row2_col2" class="data row2 col2" >                   3</td>
#                         <td id="T_c9143_row2_col3" class="data row2 col3" >                 2.0</td>
#                         <td id="T_c9143_row2_col4" class="data row2 col4" >                 1.0</td>
#                         <td id="T_c9143_row2_col5" class="data row2 col5" >                0.00</td>
#                         <td id="T_c9143_row2_col6" class="data row2 col6" >7</td>
#                         <td id="T_c9143_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_c9143_row2_col8" class="data row2 col8" >                 5.0</td>
#                         <td id="T_c9143_row2_col9" class="data row2 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_c9143_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_c9143_row3_col1" class="data row3 col1" >Chelsea</td>
#                         <td id="T_c9143_row3_col2" class="data row3 col2" >                   3</td>
#                         <td id="T_c9143_row3_col3" class="data row3 col3" >                 2.0</td>
#                         <td id="T_c9143_row3_col4" class="data row3 col4" >                 1.0</td>
#                         <td id="T_c9143_row3_col5" class="data row3 col5" >                0.00</td>
#                         <td id="T_c9143_row3_col6" class="data row3 col6" >6</td>
#                         <td id="T_c9143_row3_col7" class="data row3 col7" >1</td>
#                         <td id="T_c9143_row3_col8" class="data row3 col8" >                 5.0</td>
#                         <td id="T_c9143_row3_col9" class="data row3 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_c9143_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_c9143_row4_col1" class="data row4 col1" >Liverpool</td>
#                         <td id="T_c9143_row4_col2" class="data row4 col2" >                   3</td>
#                         <td id="T_c9143_row4_col3" class="data row4 col3" >                 2.0</td>
#                         <td id="T_c9143_row4_col4" class="data row4 col4" >                 1.0</td>
#                         <td id="T_c9143_row4_col5" class="data row4 col5" >                0.00</td>
#                         <td id="T_c9143_row4_col6" class="data row4 col6" >6</td>
#                         <td id="T_c9143_row4_col7" class="data row4 col7" >1</td>
#                         <td id="T_c9143_row4_col8" class="data row4 col8" >                 5.0</td>
#                         <td id="T_c9143_row4_col9" class="data row4 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_c9143_row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_c9143_row5_col1" class="data row5 col1" >Everton</td>
#                         <td id="T_c9143_row5_col2" class="data row5 col2" >                   3</td>
#                         <td id="T_c9143_row5_col3" class="data row5 col3" >                 2.0</td>
#                         <td id="T_c9143_row5_col4" class="data row5 col4" >                 1.0</td>
#                         <td id="T_c9143_row5_col5" class="data row5 col5" >                0.00</td>
#                         <td id="T_c9143_row5_col6" class="data row5 col6" >7</td>
#                         <td id="T_c9143_row5_col7" class="data row5 col7" >3</td>
#                         <td id="T_c9143_row5_col8" class="data row5 col8" >                 4.0</td>
#                         <td id="T_c9143_row5_col9" class="data row5 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_c9143_row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_c9143_row6_col1" class="data row6 col1" >Manchester city</td>
#                         <td id="T_c9143_row6_col2" class="data row6 col2" >                   3</td>
#                         <td id="T_c9143_row6_col3" class="data row6 col3" >                 2.0</td>
#                         <td id="T_c9143_row6_col4" class="data row6 col4" >                 0.0</td>
#                         <td id="T_c9143_row6_col5" class="data row6 col5" >                1.00</td>
#                         <td id="T_c9143_row6_col6" class="data row6 col6" >10</td>
#                         <td id="T_c9143_row6_col7" class="data row6 col7" >1</td>
#                         <td id="T_c9143_row6_col8" class="data row6 col8" >                 9.0</td>
#                         <td id="T_c9143_row6_col9" class="data row6 col9" >6</td>
#             </tr>
#             <tr>
#                                 <td id="T_c9143_row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_c9143_row7_col1" class="data row7 col1" >Brighton and hove albion</td>
#                         <td id="T_c9143_row7_col2" class="data row7 col2" >                   3</td>
#                         <td id="T_c9143_row7_col3" class="data row7 col3" >                 2.0</td>
#                         <td id="T_c9143_row7_col4" class="data row7 col4" >                 0.0</td>
#                         <td id

# %%
tab.head(16).style.format({"Games_Played": "{:20,.0f}", 
                          "Games_Won": "{:20,.0f}", 
                          "Games_Drawn": "{:20,.0f}",
                          "Games_Lost": "{:20,.0f}",
                          'GD':"{:20,.0f}"})\
                   .format({'Teams':lambda x : x.title()}).hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_7f28f_" ><thead>    <tr>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Games_Played</th>        <th class="col_heading level0 col3" >Games_Won</th>        <th class="col_heading level0 col4" >Games_Drawn</th>        <th class="col_heading level0 col5" >Games_Lost</th>        <th class="col_heading level0 col6" >GF</th>        <th class="col_heading level0 col7" >GA</th>        <th class="col_heading level0 col8" >GD</th>        <th class="col_heading level0 col9" >Points</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_7f28f_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_7f28f_row0_col1" class="data row0 col1" >Tottenham Hotspur</td>
#                         <td id="T_7f28f_row0_col2" class="data row0 col2" >                   3</td>
#                         <td id="T_7f28f_row0_col3" class="data row0 col3" >                   3</td>
#                         <td id="T_7f28f_row0_col4" class="data row0 col4" >                   0</td>
#                         <td id="T_7f28f_row0_col5" class="data row0 col5" >                   0</td>
#                         <td id="T_7f28f_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_7f28f_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_7f28f_row0_col8" class="data row0 col8" >                   3</td>
#                         <td id="T_7f28f_row0_col9" class="data row0 col9" >9</td>
#             </tr>
#             <tr>
#                                 <td id="T_7f28f_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_7f28f_row1_col1" class="data row1 col1" >West Ham United</td>
#                         <td id="T_7f28f_row1_col2" class="data row1 col2" >                   3</td>
#                         <td id="T_7f28f_row1_col3" class="data row1 col3" >                   2</td>
#                         <td id="T_7f28f_row1_col4" class="data row1 col4" >                   1</td>
#                         <td id="T_7f28f_row1_col5" class="data row1 col5" >                   0</td>
#                         <td id="T_7f28f_row1_col6" class="data row1 col6" >10</td>
#                         <td id="T_7f28f_row1_col7" class="data row1 col7" >5</td>
#                         <td id="T_7f28f_row1_col8" class="data row1 col8" >                   5</td>
#                         <td id="T_7f28f_row1_col9" class="data row1 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_7f28f_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_7f28f_row2_col1" class="data row2 col1" >Manchester United</td>
#                         <td id="T_7f28f_row2_col2" class="data row2 col2" >                   3</td>
#                         <td id="T_7f28f_row2_col3" class="data row2 col3" >                   2</td>
#                         <td id="T_7f28f_row2_col4" class="data row2 col4" >                   1</td>
#                         <td id="T_7f28f_row2_col5" class="data row2 col5" >                   0</td>
#                         <td id="T_7f28f_row2_col6" class="data row2 col6" >7</td>
#                         <td id="T_7f28f_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_7f28f_row2_col8" class="data row2 col8" >                   5</td>
#                         <td id="T_7f28f_row2_col9" class="data row2 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_7f28f_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_7f28f_row3_col1" class="data row3 col1" >Chelsea</td>
#                         <td id="T_7f28f_row3_col2" class="data row3 col2" >                   3</td>
#                         <td id="T_7f28f_row3_col3" class="data row3 col3" >                   2</td>
#                         <td id="T_7f28f_row3_col4" class="data row3 col4" >                   1</td>
#                         <td id="T_7f28f_row3_col5" class="data row3 col5" >                   0</td>
#                         <td id="T_7f28f_row3_col6" class="data row3 col6" >6</td>
#                         <td id="T_7f28f_row3_col7" class="data row3 col7" >1</td>
#                         <td id="T_7f28f_row3_col8" class="data row3 col8" >                   5</td>
#                         <td id="T_7f28f_row3_col9" class="data row3 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_7f28f_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_7f28f_row4_col1" class="data row4 col1" >Liverpool</td>
#                         <td id="T_7f28f_row4_col2" class="data row4 col2" >                   3</td>
#                         <td id="T_7f28f_row4_col3" class="data row4 col3" >                   2</td>
#                         <td id="T_7f28f_row4_col4" class="data row4 col4" >                   1</td>
#                         <td id="T_7f28f_row4_col5" class="data row4 col5" >                   0</td>
#                         <td id="T_7f28f_row4_col6" class="data row4 col6" >6</td>
#                         <td id="T_7f28f_row4_col7" class="data row4 col7" >1</td>
#                         <td id="T_7f28f_row4_col8" class="data row4 col8" >                   5</td>
#                         <td id="T_7f28f_row4_col9" class="data row4 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_7f28f_row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_7f28f_row5_col1" class="data row5 col1" >Everton</td>
#                         <td id="T_7f28f_row5_col2" class="data row5 col2" >                   3</td>
#                         <td id="T_7f28f_row5_col3" class="data row5 col3" >                   2</td>
#                         <td id="T_7f28f_row5_col4" class="data row5 col4" >                   1</td>
#                         <td id="T_7f28f_row5_col5" class="data row5 col5" >                   0</td>
#                         <td id="T_7f28f_row5_col6" class="data row5 col6" >7</td>
#                         <td id="T_7f28f_row5_col7" class="data row5 col7" >3</td>
#                         <td id="T_7f28f_row5_col8" class="data row5 col8" >                   4</td>
#                         <td id="T_7f28f_row5_col9" class="data row5 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_7f28f_row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_7f28f_row6_col1" class="data row6 col1" >Manchester City</td>
#                         <td id="T_7f28f_row6_col2" class="data row6 col2" >                   3</td>
#                         <td id="T_7f28f_row6_col3" class="data row6 col3" >                   2</td>
#                         <td id="T_7f28f_row6_col4" class="data row6 col4" >                   0</td>
#                         <td id="T_7f28f_row6_col5" class="data row6 col5" >                   1</td>
#                         <td id="T_7f28f_row6_col6" class="data row6 col6" >10</td>
#                         <td id="T_7f28f_row6_col7" class="data row6 col7" >1</td>
#                         <td id="T_7f28f_row6_col8" class="data row6 col8" >                   9</td>
#                         <td id="T_7f28f_row6_col9" class="data row6 col9" >6</td>
#             </tr>
#             <tr>
#                                 <td id="T_7f28f_row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_7f28f_row7_col1" class="data row7 col1" >Brighton And Hove Albion</td>
#                         <td id="T_7f28f_row7_col2" class="data row7 col2" >                   3</td>
#                         <td id="T_7f28f_row7_col3" class="data row7 col3" >                   2</td>
#                         <td id="T_7f28f_row7_col4" class="data row7 col4" >                   0</td>
#                         <td id

# %% [markdown]
# Let format the colors of our numerical and categorical function, we can acheive this by running an anonymous function that gives the values a particular color if the data type is a string and another color if it is an integer, the code is shown below:

# %%
tab.head(16).style.format({"Games_Played": "{:20,.0f}", 
                          "Games_Won": "{:20,.0f}", 
                          "Games_Drawn": "{:20,.0f}",
                          "Games_Lost": "{:20,.0f}",
                          'GD':"{:20,.0f}"})\
                   .format({'Teams':lambda x : x.title()})\
                   .hide_index()\
                   .applymap(lambda x: f"color: {'red' if isinstance(x,str) else 'blue'}")
# Out:
# <style  type="text/css" >
# #T_9dbdb_row0_col0,#T_9dbdb_row0_col2,#T_9dbdb_row0_col3,#T_9dbdb_row0_col4,#T_9dbdb_row0_col5,#T_9dbdb_row0_col6,#T_9dbdb_row0_col7,#T_9dbdb_row0_col8,#T_9dbdb_row0_col9,#T_9dbdb_row1_col0,#T_9dbdb_row1_col2,#T_9dbdb_row1_col3,#T_9dbdb_row1_col4,#T_9dbdb_row1_col5,#T_9dbdb_row1_col6,#T_9dbdb_row1_col7,#T_9dbdb_row1_col8,#T_9dbdb_row1_col9,#T_9dbdb_row2_col0,#T_9dbdb_row2_col2,#T_9dbdb_row2_col3,#T_9dbdb_row2_col4,#T_9dbdb_row2_col5,#T_9dbdb_row2_col6,#T_9dbdb_row2_col7,#T_9dbdb_row2_col8,#T_9dbdb_row2_col9,#T_9dbdb_row3_col0,#T_9dbdb_row3_col2,#T_9dbdb_row3_col3,#T_9dbdb_row3_col4,#T_9dbdb_row3_col5,#T_9dbdb_row3_col6,#T_9dbdb_row3_col7,#T_9dbdb_row3_col8,#T_9dbdb_row3_col9,#T_9dbdb_row4_col0,#T_9dbdb_row4_col2,#T_9dbdb_row4_col3,#T_9dbdb_row4_col4,#T_9dbdb_row4_col5,#T_9dbdb_row4_col6,#T_9dbdb_row4_col7,#T_9dbdb_row4_col8,#T_9dbdb_row4_col9,#T_9dbdb_row5_col0,#T_9dbdb_row5_col2,#T_9dbdb_row5_col3,#T_9dbdb_row5_col4,#T_9dbdb_row5_col5,#T_9dbdb_row5_col6,#T_9dbdb_row5_col7,#T_9dbdb_row5_col8,#T_9dbdb_row5_col9,#T_9dbdb_row6_col0,#T_9dbdb_row6_col2,#T_9dbdb_row6_col3,#T_9dbdb_row6_col4,#T_9dbdb_row6_col5,#T_9dbdb_row6_col6,#T_9dbdb_row6_col7,#T_9dbdb_row6_col8,#T_9dbdb_row6_col9,#T_9dbdb_row7_col0,#T_9dbdb_row7_col2,#T_9dbdb_row7_col3,#T_9dbdb_row7_col4,#T_9dbdb_row7_col5,#T_9dbdb_row7_col6,#T_9dbdb_row7_col7,#T_9dbdb_row7_col8,#T_9dbdb_row7_col9,#T_9dbdb_row8_col0,#T_9dbdb_row8_col2,#T_9dbdb_row8_col3,#T_9dbdb_row8_col4,#T_9dbdb_row8_col5,#T_9dbdb_row8_col6,#T_9dbdb_row8_col7,#T_9dbdb_row8_col8,#T_9dbdb_row8_col9,#T_9dbdb_row9_col0,#T_9dbdb_row9_col2,#T_9dbdb_row9_col3,#T_9dbdb_row9_col4,#T_9dbdb_row9_col5,#T_9dbdb_row9_col6,#T_9dbdb_row9_col7,#T_9dbdb_row9_col8,#T_9dbdb_row9_col9,#T_9dbdb_row10_col0,#T_9dbdb_row10_col2,#T_9dbdb_row10_col3,#T_9dbdb_row10_col4,#T_9dbdb_row10_col5,#T_9dbdb_row10_col6,#T_9dbdb_row10_col7,#T_9dbdb_row10_col8,#T_9dbdb_row10_col9,#T_9dbdb_row11_col0,#T_9dbdb_row11_col2,#T_9dbdb_row11_col3,#T_9dbdb_row11_col4,#T_9dbdb_row11_col5,#T_9dbdb_row11_col6,#T_9dbdb_row11_col7,#T_9dbdb_row11_col8,#T_9dbdb_row11_col9,#T_9dbdb_row12_col0,#T_9dbdb_row12_col2,#T_9dbdb_row12_col3,#T_9dbdb_row12_col4,#T_9dbdb_row12_col5,#T_9dbdb_row12_col6,#T_9dbdb_row12_col7,#T_9dbdb_row12_col8,#T_9dbdb_row12_col9,#T_9dbdb_row13_col0,#T_9dbdb_row13_col2,#T_9dbdb_row13_col3,#T_9dbdb_row13_col4,#T_9dbdb_row13_col5,#T_9dbdb_row13_col6,#T_9dbdb_row13_col7,#T_9dbdb_row13_col8,#T_9dbdb_row13_col9,#T_9dbdb_row14_col0,#T_9dbdb_row14_col2,#T_9dbdb_row14_col3,#T_9dbdb_row14_col4,#T_9dbdb_row14_col5,#T_9dbdb_row14_col6,#T_9dbdb_row14_col7,#T_9dbdb_row14_col8,#T_9dbdb_row14_col9,#T_9dbdb_row15_col0,#T_9dbdb_row15_col2,#T_9dbdb_row15_col3,#T_9dbdb_row15_col4,#T_9dbdb_row15_col5,#T_9dbdb_row15_col6,#T_9dbdb_row15_col7,#T_9dbdb_row15_col8,#T_9dbdb_row15_col9{
#             color:  blue;
#         }#T_9dbdb_row0_col1,#T_9dbdb_row1_col1,#T_9dbdb_row2_col1,#T_9dbdb_row3_col1,#T_9dbdb_row4_col1,#T_9dbdb_row5_col1,#T_9dbdb_row6_col1,#T_9dbdb_row7_col1,#T_9dbdb_row8_col1,#T_9dbdb_row9_col1,#T_9dbdb_row10_col1,#T_9dbdb_row11_col1,#T_9dbdb_row12_col1,#T_9dbdb_row13_col1,#T_9dbdb_row14_col1,#T_9dbdb_row15_col1{
#             color:  red;
#         }</style><table id="T_9dbdb_" ><thead>    <tr>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Games_Played</th>        <th class="col_heading level0 col3" >Games_Won</th>        <th class="col_heading level0 col4" >Games_Drawn</th>        <th class="col_heading level0 col5" >Games_Lost</th>        <th class="col_heading level0 col6" >GF</th>        <th class="col_heading level0 col7" >GA</th>        <th class="col_heading level0 col8" >GD</th>        <th class="col_heading level0 col9" >Points</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9dbdb_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_9dbdb_row0_col1" class="data row0 col1" >Tottenham Hotspur</td>
#                         <td id="T_9dbdb_row0_col2" class="data row0 col2" >                   3</td>
#                         <td id="T_9dbdb_row0_col3" class="data row0 col3" >                   3</td>
#                         <td id="T_9dbdb_row0_col4" class="data row0 col4" >                   0</td>
#                         <td id="T_9dbdb_row0_col5" class="data row0 col5" >                   0</td>
#                         <td id="T_9dbdb_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_9dbdb_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_9dbdb_row0_col8" class="data row0 col8" >                   3</td>
#                         <td id="T_9dbdb_row0_col9" class="data row0 col9" >9</td>
#             </tr>
#             <tr>
#                                 <td id="T_9dbdb_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_9dbdb_row1_col1" class="data row1 col1" >West Ham United</td>
#                         <td id="T_9dbdb_row1_col2" class="data row1 col2" >                   3</td>
#                         <td id="T_9dbdb_row1_col3" class="data row1 col3" >                   2</td>
#                         <td id="T_9dbdb_row1_col4" class="data row1 col4" >                   1</td>
#                         <td id="T_9dbdb_row1_col5" class="data row1 col5" >                   0</td>
#                         <td id="T_9dbdb_row1_col6" class="data row1 col6" >10</td>
#                         <td id="T_9dbdb_row1_col7" class="data row1 col7" >5</td>
#                         <td id="T_9dbdb_row1_col8" class="data row1 col8" >                   5</td>
#                         <td id="T_9dbdb_row1_col9" class="data row1 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_9dbdb_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_9dbdb_row2_col1" class="data row2 col1" >Manchester United</td>
#                         <td id="T_9dbdb_row2_col2" class="data row2 col2" >                   3</td>
#                         <td id="T_9dbdb_row2_col3" class="data row2 col3" >                   2</td>
#                         <td id="T_9dbdb_row2_col4" class="data row2 col4" >                   1</td>
#                         <td id="T_9dbdb_row2_col5" class="data row2 col5" >                   0</td>
#                         <td id="T_9dbdb_row2_col6" class="data row2 col6" >7</td>
#                         <td id="T_9dbdb_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_9dbdb_row2_col8" class="data row2 col8" >                   5</td>
#                         <td id="T_9dbdb_row2_col9" class="data row2 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_9dbdb_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_9dbdb_row3_col1" class="data row3 col1" >Chelsea</td>
#                         <td id="T_9dbdb_row3_col2" class="data row3 col2" >                   3</td>
#                         <td id="T_9dbdb_row3_col3" class="data row3 col3" >                   2</td>
#                         <td id="T_9dbdb_row3_col4" class="data row3 col4" >                   1</td>
#                         <td id="T_9dbdb_row3_col5" class="data row3 col5" >                   0</td>
#                         <td id="T_9dbdb_row3_col6" class="data row3 col6" >6</td>
#                         <td id="T_9dbdb_row3_col7" class="data row3 col7" >1</td>
#                         <td id="T_9dbdb_row3_col8" class="data row3 col8" >                   5</td>
#                         <td id="T_9dbdb_row3_col9" class="data row3 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_9dbdb_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_9dbdb_row4_col1" class="data row4 col1" >Liverpool</td>
#                         <td id="T_9dbdb_row4_col2" class="data row4 col2" >

# %% [markdown]
# ### Using the `highlight_max` and `highlight_min` functions

# %% [markdown]
# This is another excellent feature that comes with the pandas styling API, they operate column wise on integer features and highlight the minimum and maximum values of each column features.

# %%
tab.head(20).style.format({"Games_Played": "{:20,.0f}", 
                          "Games_Won": "{:20,.0f}", 
                          "Games_Lost": "{:20,.0f}",
                          "Games_Drawn":"{:20,.0f}"})\
                 .format({"Teams": lambda x:x.title()})\
                 .hide_index()\
                .highlight_max(color='lightgreen').highlight_min(color='#cd4f39')
# Out:
# <style  type="text/css" >
# #T_ce310_row0_col0,#T_ce310_row0_col4,#T_ce310_row0_col5,#T_ce310_row0_col7,#T_ce310_row1_col5,#T_ce310_row2_col5,#T_ce310_row3_col5,#T_ce310_row4_col5,#T_ce310_row5_col5,#T_ce310_row6_col4,#T_ce310_row7_col4,#T_ce310_row8_col4,#T_ce310_row9_col5,#T_ce310_row11_col4,#T_ce310_row12_col3,#T_ce310_row13_col3,#T_ce310_row14_col3,#T_ce310_row15_col3,#T_ce310_row16_col3,#T_ce310_row17_col3,#T_ce310_row17_col4,#T_ce310_row17_col6,#T_ce310_row17_col9,#T_ce310_row18_col3,#T_ce310_row18_col4,#T_ce310_row18_col8,#T_ce310_row18_col9,#T_ce310_row19_col3,#T_ce310_row19_col4,#T_ce310_row19_col6,#T_ce310_row19_col8,#T_ce310_row19_col9{
#             background-color:  #cd4f39;
#         }#T_ce310_row0_col2,#T_ce310_row1_col2,#T_ce310_row2_col2,#T_ce310_row3_col2,#T_ce310_row4_col2,#T_ce310_row5_col2,#T_ce310_row6_col2,#T_ce310_row7_col2,#T_ce310_row8_col2,#T_ce310_row9_col2,#T_ce310_row10_col2,#T_ce310_row11_col2,#T_ce310_row12_col2,#T_ce310_row13_col2,#T_ce310_row14_col2,#T_ce310_row15_col2,#T_ce310_row16_col2,#T_ce310_row17_col2,#T_ce310_row18_col2,#T_ce310_row19_col2{
#             background-color:  lightgreen;
#             background-color:  #cd4f39;
#         }#T_ce310_row0_col3,#T_ce310_row0_col9,#T_ce310_row1_col6,#T_ce310_row6_col6,#T_ce310_row6_col8,#T_ce310_row9_col4,#T_ce310_row12_col4,#T_ce310_row13_col4,#T_ce310_row14_col4,#T_ce310_row17_col5,#T_ce310_row18_col5,#T_ce310_row18_col7,#T_ce310_row19_col0,#T_ce310_row19_col5{
#             background-color:  lightgreen;
#         }</style><table id="T_ce310_" ><thead>    <tr>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Games_Played</th>        <th class="col_heading level0 col3" >Games_Won</th>        <th class="col_heading level0 col4" >Games_Drawn</th>        <th class="col_heading level0 col5" >Games_Lost</th>        <th class="col_heading level0 col6" >GF</th>        <th class="col_heading level0 col7" >GA</th>        <th class="col_heading level0 col8" >GD</th>        <th class="col_heading level0 col9" >Points</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ce310_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_ce310_row0_col1" class="data row0 col1" >Tottenham Hotspur</td>
#                         <td id="T_ce310_row0_col2" class="data row0 col2" >                   3</td>
#                         <td id="T_ce310_row0_col3" class="data row0 col3" >                   3</td>
#                         <td id="T_ce310_row0_col4" class="data row0 col4" >                   0</td>
#                         <td id="T_ce310_row0_col5" class="data row0 col5" >                   0</td>
#                         <td id="T_ce310_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_ce310_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_ce310_row0_col8" class="data row0 col8" >3</td>
#                         <td id="T_ce310_row0_col9" class="data row0 col9" >9</td>
#             </tr>
#             <tr>
#                                 <td id="T_ce310_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_ce310_row1_col1" class="data row1 col1" >West Ham United</td>
#                         <td id="T_ce310_row1_col2" class="data row1 col2" >                   3</td>
#                         <td id="T_ce310_row1_col3" class="data row1 col3" >                   2</td>
#                         <td id="T_ce310_row1_col4" class="data row1 col4" >                   1</td>
#                         <td id="T_ce310_row1_col5" class="data row1 col5" >                   0</td>
#                         <td id="T_ce310_row1_col6" class="data row1 col6" >10</td>
#                         <td id="T_ce310_row1_col7" class="data row1 col7" >5</td>
#                         <td id="T_ce310_row1_col8" class="data row1 col8" >5</td>
#                         <td id="T_ce310_row1_col9" class="data row1 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_ce310_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_ce310_row2_col1" class="data row2 col1" >Manchester United</td>
#                         <td id="T_ce310_row2_col2" class="data row2 col2" >                   3</td>
#                         <td id="T_ce310_row2_col3" class="data row2 col3" >                   2</td>
#                         <td id="T_ce310_row2_col4" class="data row2 col4" >                   1</td>
#                         <td id="T_ce310_row2_col5" class="data row2 col5" >                   0</td>
#                         <td id="T_ce310_row2_col6" class="data row2 col6" >7</td>
#                         <td id="T_ce310_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_ce310_row2_col8" class="data row2 col8" >5</td>
#                         <td id="T_ce310_row2_col9" class="data row2 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_ce310_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_ce310_row3_col1" class="data row3 col1" >Chelsea</td>
#                         <td id="T_ce310_row3_col2" class="data row3 col2" >                   3</td>
#                         <td id="T_ce310_row3_col3" class="data row3 col3" >                   2</td>
#                         <td id="T_ce310_row3_col4" class="data row3 col4" >                   1</td>
#                         <td id="T_ce310_row3_col5" class="data row3 col5" >                   0</td>
#                         <td id="T_ce310_row3_col6" class="data row3 col6" >6</td>
#                         <td id="T_ce310_row3_col7" class="data row3 col7" >1</td>
#                         <td id="T_ce310_row3_col8" class="data row3 col8" >5</td>
#                         <td id="T_ce310_row3_col9" class="data row3 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_ce310_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_ce310_row4_col1" class="data row4 col1" >Liverpool</td>
#                         <td id="T_ce310_row4_col2" class="data row4 col2" >                   3</td>
#                         <td id="T_ce310_row4_col3" class="data row4 col3" >                   2</td>
#                         <td id="T_ce310_row4_col4" class="data row4 col4" >                   1</td>
#                         <td id="T_ce310_row4_col5" class="data row4 col5" >                   0</td>
#                         <td id="T_ce310_row4_col6" class="data row4 col6" >6</td>
#                         <td id="T_ce310_row4_col7" class="data row4 col7" >1</td>
#                         <td id="T_ce310_row4_col8" class="data row4 col8" >5</td>
#                         <td id="T_ce310_row4_col9" class="data row4 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_ce310_row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_ce310_row5_col1" class="data row5 col1" >Everton</td>
#                         <td id="T_ce310_row5_col2" class="data row5 col2" >                   3</td>
#                         <td id="T_ce310_row5_col3" class="data row5 col3" >                   2</td>
#                         <td id="T_ce310_row5_col4" class="data row5 col4" >                   1</td>
#                         <td id="T_ce310_row5_col5" class="data row5 col5" >                   0</td>
#                         <td id="T_ce310_row5_col6" class="data row5 col6" >7</td>
#                         <td id="T_ce310_row5_col7" class="data row5 col7" >3</td>
#                         <td id="T_ce310_row5_col8" class="data row5 col8" >4</td>
#                         <td id="T_ce310_row5_col9" class="data row5 col9" >7</td>
#             </tr>
#             <tr>
#                                 <td id="T_ce310_row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_ce31

# %% [markdown]
# ### Using the `background_gradients` function

# %% [markdown]
# This pandas method also operates column-wise and colors the integer feature columns like an heatmap, the high numbers would be formatted with deeper colors and the low numbers carry the lighter colors depending on the palettes used, An example is carried out on our table below:

# %%
tab.head(10).style.format({"Points": "{:20,.0f}", 
                          "Games_Lost": "{:20,.0f}", 
                          "Games_Played": "{:20,.0f}",
                          "Games_Won":"{:20,.0f}"})\
                     .format({"Teams": lambda x:x.title()})\
                 .hide_index()\
                 .background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
# #T_37564_row0_col0,#T_37564_row0_col2,#T_37564_row0_col4,#T_37564_row0_col5,#T_37564_row0_col6,#T_37564_row0_col7,#T_37564_row1_col2,#T_37564_row1_col5,#T_37564_row2_col2,#T_37564_row2_col5,#T_37564_row3_col2,#T_37564_row3_col5,#T_37564_row4_col2,#T_37564_row4_col5,#T_37564_row5_col2,#T_37564_row5_col5,#T_37564_row6_col2,#T_37564_row6_col4,#T_37564_row7_col2,#T_37564_row7_col4,#T_37564_row8_col2,#T_37564_row8_col4,#T_37564_row8_col8,#T_37564_row9_col2,#T_37564_row9_col3,#T_37564_row9_col5,#T_37564_row9_col6,#T_37564_row9_col9{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_37564_row0_col3,#T_37564_row0_col9,#T_37564_row1_col6,#T_37564_row1_col7,#T_37564_row6_col5,#T_37564_row6_col6,#T_37564_row6_col8,#T_37564_row7_col5,#T_37564_row8_col5,#T_37564_row8_col7,#T_37564_row9_col0,#T_37564_row9_col4{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_37564_row0_col8,#T_37564_row2_col7{
#             background-color:  #94c4df;
#             color:  #000000;
#         }#T_37564_row1_col0{
#             background-color:  #e1edf8;
#             color:  #000000;
#         }#T_37564_row1_col3,#T_37564_row1_col4,#T_37564_row1_col9,#T_37564_row2_col3,#T_37564_row2_col4,#T_37564_row2_col9,#T_37564_row3_col3,#T_37564_row3_col4,#T_37564_row3_col9,#T_37564_row4_col3,#T_37564_row4_col4,#T_37564_row4_col9,#T_37564_row5_col3,#T_37564_row5_col4,#T_37564_row5_col8,#T_37564_row5_col9,#T_37564_row6_col3,#T_37564_row7_col3,#T_37564_row8_col3{
#             background-color:  #6aaed6;
#             color:  #000000;
#         }#T_37564_row1_col8,#T_37564_row2_col8,#T_37564_row3_col8,#T_37564_row4_col8,#T_37564_row5_col7,#T_37564_row7_col7{
#             background-color:  #4a98c9;
#             color:  #000000;
#         }#T_37564_row2_col0{
#             background-color:  #ccdff1;
#             color:  #000000;
#         }#T_37564_row2_col6,#T_37564_row5_col6{
#             background-color:  #539ecd;
#             color:  #000000;
#         }#T_37564_row3_col0{
#             background-color:  #abd0e6;
#             color:  #000000;
#         }#T_37564_row3_col6,#T_37564_row4_col6{
#             background-color:  #89bedc;
#             color:  #000000;
#         }#T_37564_row3_col7,#T_37564_row4_col7,#T_37564_row6_col7,#T_37564_row7_col8,#T_37564_row9_col7{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_37564_row4_col0{
#             background-color:  #82bbdb;
#             color:  #000000;
#         }#T_37564_row5_col0{
#             background-color:  #58a1cf;
#             color:  #000000;
#         }#T_37564_row6_col0{
#             background-color:  #3787c0;
#             color:  #000000;
#         }#T_37564_row6_col9,#T_37564_row7_col9,#T_37564_row8_col9{
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_37564_row7_col0{
#             background-color:  #1b69af;
#             color:  #f1f1f1;
#         }#T_37564_row7_col6,#T_37564_row8_col6{
#             background-color:  #dbe9f6;
#             color:  #000000;
#         }#T_37564_row8_col0{
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }#T_37564_row9_col8{
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }</style><table id="T_37564_" ><thead>    <tr>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Games_Played</th>        <th class="col_heading level0 col3" >Games_Won</th>        <th class="col_heading level0 col4" >Games_Drawn</th>        <th class="col_heading level0 col5" >Games_Lost</th>        <th class="col_heading level0 col6" >GF</th>        <th class="col_heading level0 col7" >GA</th>        <th class="col_heading level0 col8" >GD</th>        <th class="col_heading level0 col9" >Points</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_37564_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_37564_row0_col1" class="data row0 col1" >Tottenham Hotspur</td>
#                         <td id="T_37564_row0_col2" class="data row0 col2" >                   3</td>
#                         <td id="T_37564_row0_col3" class="data row0 col3" >                   3</td>
#                         <td id="T_37564_row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_37564_row0_col5" class="data row0 col5" >                   0</td>
#                         <td id="T_37564_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_37564_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_37564_row0_col8" class="data row0 col8" >3</td>
#                         <td id="T_37564_row0_col9" class="data row0 col9" >                   9</td>
#             </tr>
#             <tr>
#                                 <td id="T_37564_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_37564_row1_col1" class="data row1 col1" >West Ham United</td>
#                         <td id="T_37564_row1_col2" class="data row1 col2" >                   3</td>
#                         <td id="T_37564_row1_col3" class="data row1 col3" >                   2</td>
#                         <td id="T_37564_row1_col4" class="data row1 col4" >1</td>
#                         <td id="T_37564_row1_col5" class="data row1 col5" >                   0</td>
#                         <td id="T_37564_row1_col6" class="data row1 col6" >10</td>
#                         <td id="T_37564_row1_col7" class="data row1 col7" >5</td>
#                         <td id="T_37564_row1_col8" class="data row1 col8" >5</td>
#                         <td id="T_37564_row1_col9" class="data row1 col9" >                   7</td>
#             </tr>
#             <tr>
#                                 <td id="T_37564_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_37564_row2_col1" class="data row2 col1" >Manchester United</td>
#                         <td id="T_37564_row2_col2" class="data row2 col2" >                   3</td>
#                         <td id="T_37564_row2_col3" class="data row2 col3" >                   2</td>
#                         <td id="T_37564_row2_col4" class="data row2 col4" >1</td>
#                         <td id="T_37564_row2_col5" class="data row2 col5" >                   0</td>
#                         <td id="T_37564_row2_col6" class="data row2 col6" >7</td>
#                         <td id="T_37564_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_37564_row2_col8" class="data row2 col8" >5</td>
#                         <td id="T_37564_row2_col9" class="data row2 col9" >                   7</td>
#             </tr>
#             <tr>
#                                 <td id="T_37564_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_37564_row3_col1" class="data row3 col1" >Chelsea</td>
#                         <td id="T_37564_row3_col2" class="data row3 col2" >                   3</td>
#                         <td id="T_37564_row3_col3" class="data row3 col3" >                   2</td>
#                         <td id="T_37564_row3_col4" class="data row3 col4" >1</td>
#                         <td id="T_37564_row3_col5" class="data row3 col5" >                   0</td>
#                         <td id="T_37564_row3_col6" class="data row3 col6" >6</td>
#                         <td id="T_37564_row3_col7" class="data row3 col7" >1</td>
#                         <td id="T_37564_row3_col8" class="data row3 col8" >5</td>
#                         <td id="T_37564_row3_col9" class="data row3 col9" >                   7</td>
#             </tr>
#             <tr>
#                                 <td id="T_37564_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_37564_row4_col1" class="data row4 col1" >Liverpool</td>
#                         <td id="T_37564_row4_col2" class="data row4 col2" >                   3</td>

# %% [markdown]
# ### Using the `set_properties()` function

# %% [markdown]
# we can also use the `set_properties()` function to format our dataframe, the syntax is similar to the CSS syntax.

# %%
tab.head(10).style.set_properties(**{'background-color': 'black',                                                   
                                    'color': 'lawngreen',                       
                                    'border-color': 'blue'})
# Out:
# <style  type="text/css" >
# #T_3d550_row0_col0,#T_3d550_row0_col1,#T_3d550_row0_col2,#T_3d550_row0_col3,#T_3d550_row0_col4,#T_3d550_row0_col5,#T_3d550_row0_col6,#T_3d550_row0_col7,#T_3d550_row0_col8,#T_3d550_row0_col9,#T_3d550_row1_col0,#T_3d550_row1_col1,#T_3d550_row1_col2,#T_3d550_row1_col3,#T_3d550_row1_col4,#T_3d550_row1_col5,#T_3d550_row1_col6,#T_3d550_row1_col7,#T_3d550_row1_col8,#T_3d550_row1_col9,#T_3d550_row2_col0,#T_3d550_row2_col1,#T_3d550_row2_col2,#T_3d550_row2_col3,#T_3d550_row2_col4,#T_3d550_row2_col5,#T_3d550_row2_col6,#T_3d550_row2_col7,#T_3d550_row2_col8,#T_3d550_row2_col9,#T_3d550_row3_col0,#T_3d550_row3_col1,#T_3d550_row3_col2,#T_3d550_row3_col3,#T_3d550_row3_col4,#T_3d550_row3_col5,#T_3d550_row3_col6,#T_3d550_row3_col7,#T_3d550_row3_col8,#T_3d550_row3_col9,#T_3d550_row4_col0,#T_3d550_row4_col1,#T_3d550_row4_col2,#T_3d550_row4_col3,#T_3d550_row4_col4,#T_3d550_row4_col5,#T_3d550_row4_col6,#T_3d550_row4_col7,#T_3d550_row4_col8,#T_3d550_row4_col9,#T_3d550_row5_col0,#T_3d550_row5_col1,#T_3d550_row5_col2,#T_3d550_row5_col3,#T_3d550_row5_col4,#T_3d550_row5_col5,#T_3d550_row5_col6,#T_3d550_row5_col7,#T_3d550_row5_col8,#T_3d550_row5_col9,#T_3d550_row6_col0,#T_3d550_row6_col1,#T_3d550_row6_col2,#T_3d550_row6_col3,#T_3d550_row6_col4,#T_3d550_row6_col5,#T_3d550_row6_col6,#T_3d550_row6_col7,#T_3d550_row6_col8,#T_3d550_row6_col9,#T_3d550_row7_col0,#T_3d550_row7_col1,#T_3d550_row7_col2,#T_3d550_row7_col3,#T_3d550_row7_col4,#T_3d550_row7_col5,#T_3d550_row7_col6,#T_3d550_row7_col7,#T_3d550_row7_col8,#T_3d550_row7_col9,#T_3d550_row8_col0,#T_3d550_row8_col1,#T_3d550_row8_col2,#T_3d550_row8_col3,#T_3d550_row8_col4,#T_3d550_row8_col5,#T_3d550_row8_col6,#T_3d550_row8_col7,#T_3d550_row8_col8,#T_3d550_row8_col9,#T_3d550_row9_col0,#T_3d550_row9_col1,#T_3d550_row9_col2,#T_3d550_row9_col3,#T_3d550_row9_col4,#T_3d550_row9_col5,#T_3d550_row9_col6,#T_3d550_row9_col7,#T_3d550_row9_col8,#T_3d550_row9_col9{
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  blue;
#         }</style><table id="T_3d550_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Games_Played</th>        <th class="col_heading level0 col3" >Games_Won</th>        <th class="col_heading level0 col4" >Games_Drawn</th>        <th class="col_heading level0 col5" >Games_Lost</th>        <th class="col_heading level0 col6" >GF</th>        <th class="col_heading level0 col7" >GA</th>        <th class="col_heading level0 col8" >GD</th>        <th class="col_heading level0 col9" >Points</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3d550_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3d550_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_3d550_row0_col1" class="data row0 col1" >Tottenham Hotspur</td>
#                         <td id="T_3d550_row0_col2" class="data row0 col2" >3</td>
#                         <td id="T_3d550_row0_col3" class="data row0 col3" >3</td>
#                         <td id="T_3d550_row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_3d550_row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_3d550_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_3d550_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_3d550_row0_col8" class="data row0 col8" >3</td>
#                         <td id="T_3d550_row0_col9" class="data row0 col9" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_3d550_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3d550_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_3d550_row1_col1" class="data row1 col1" >West Ham United</td>
#                         <td id="T_3d550_row1_col2" class="data row1 col2" >3</td>
#                         <td id="T_3d550_row1_col3" class="data row1 col3" >2</td>
#                         <td id="T_3d550_row1_col4" class="data row1 col4" >1</td>
#                         <td id="T_3d550_row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_3d550_row1_col6" class="data row1 col6" >10</td>
#                         <td id="T_3d550_row1_col7" class="data row1 col7" >5</td>
#                         <td id="T_3d550_row1_col8" class="data row1 col8" >5</td>
#                         <td id="T_3d550_row1_col9" class="data row1 col9" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_3d550_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3d550_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_3d550_row2_col1" class="data row2 col1" >Manchester United</td>
#                         <td id="T_3d550_row2_col2" class="data row2 col2" >3</td>
#                         <td id="T_3d550_row2_col3" class="data row2 col3" >2</td>
#                         <td id="T_3d550_row2_col4" class="data row2 col4" >1</td>
#                         <td id="T_3d550_row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_3d550_row2_col6" class="data row2 col6" >7</td>
#                         <td id="T_3d550_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_3d550_row2_col8" class="data row2 col8" >5</td>
#                         <td id="T_3d550_row2_col9" class="data row2 col9" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_3d550_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3d550_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_3d550_row3_col1" class="data row3 col1" >Chelsea</td>
#                         <td id="T_3d550_row3_col2" class="data row3 col2" >3</td>
#                         <td id="T_3d550_row3_col3" class="data row3 col3" >2</td>
#                         <td id="T_3d550_row3_col4" class="data row3 col4" >1</td>
#                         <td id="T_3d550_row3_col5" class="data row3 col5" >0</td>
#                         <td id="T_3d550_row3_col6" class="data row3 col6" >6</td>
#                         <td id="T_3d550_row3_col7" class="data row3 col7" >1</td>
#                         <td id="T_3d550_row3_col8" class="data row3 col8" >5</td>
#                         <td id="T_3d550_row3_col9" class="data row3 col9" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_3d550_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3d550_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_3d550_row4_col1" class="data row4 col1" >Liverpool</td>
#                         <td id="T_3d550_row4_col2" class="data row4 col2" >3</td>
#                         <td id="T_3d550_row4_col3" class="data row4 col3" >2</td>
#                         <td id="T_3d550_row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_3d550_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_3d550_row4_col6" class="data row4 col6" >6</td>
#                         <td id="T_3d550_row4_col7" class="data row4 col7" >1</td>
#                         <td id="T_3d550_row4_col8" class="data row4 col8" >5</td>
#                         <td id="T_3d550_row4_col9" class="data row4 col9" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_3d550_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3d550_row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_3d550_row5_col1" class="data row5 col1" >Everton</td>
#                         <td id="T_3d550_row5_col2" class="data row5 col2" >3</td>
#                         <td id="T_3d550_row5_col3" class="data row5 col3" >2</td>
#                         <td id="T_3d5

# %% [markdown]
# We can format each integer oriented column of our dataset using the .`bar()` function. The syntax is shown below.

# %%
a = tab.head(20).style.format({"GA": "{:20,.0f}", 
                          "GF": "{:20,.0f}", 
                          "GD": "{:20,.0f}",
                          "Points":"{:20,.0f}"})\
                 .format({"Teams": lambda x:x.title()})\
                 .hide_index()\
                 .bar(subset=["GF",], color='lightgreen')\
                 .bar(subset=["GA"], color='#ee1f5f')\
                 .bar(subset=["GD"], color='#FFA07A')\
                 .bar(subset = ['Games_Won'], color = '#15C6DE')\
                 .bar(subset = ['Games_Drawn'], color = '#F0EC10')\
                 .bar(subset = ['Games_Lost'], color = '#0E28E8')

a
# Out:
# <style  type="text/css" >
# #T_0a1da_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#15C6DE 100.0%, transparent 100.0%);
#         }#T_0a1da_row0_col4,#T_0a1da_row0_col5,#T_0a1da_row0_col7,#T_0a1da_row1_col5,#T_0a1da_row2_col5,#T_0a1da_row3_col5,#T_0a1da_row4_col5,#T_0a1da_row5_col5,#T_0a1da_row6_col4,#T_0a1da_row7_col4,#T_0a1da_row8_col4,#T_0a1da_row9_col5,#T_0a1da_row11_col4,#T_0a1da_row12_col3,#T_0a1da_row13_col3,#T_0a1da_row14_col3,#T_0a1da_row15_col3,#T_0a1da_row16_col3,#T_0a1da_row17_col3,#T_0a1da_row17_col4,#T_0a1da_row17_col6,#T_0a1da_row18_col3,#T_0a1da_row18_col4,#T_0a1da_row18_col8,#T_0a1da_row19_col3,#T_0a1da_row19_col4,#T_0a1da_row19_col6,#T_0a1da_row19_col8{
#             width:  10em;
#              height:  80%;
#         }#T_0a1da_row0_col6,#T_0a1da_row9_col6,#T_0a1da_row11_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 30.0%, transparent 30.0%);
#         }#T_0a1da_row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 66.7%, transparent 66.7%);
#         }#T_0a1da_row1_col3,#T_0a1da_row2_col3,#T_0a1da_row3_col3,#T_0a1da_row4_col3,#T_0a1da_row5_col3,#T_0a1da_row6_col3,#T_0a1da_row7_col3,#T_0a1da_row8_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#15C6DE 66.7%, transparent 66.7%);
#         }#T_0a1da_row1_col4,#T_0a1da_row2_col4,#T_0a1da_row3_col4,#T_0a1da_row4_col4,#T_0a1da_row5_col4,#T_0a1da_row10_col4,#T_0a1da_row15_col4,#T_0a1da_row16_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#F0EC10 50.0%, transparent 50.0%);
#         }#T_0a1da_row1_col6,#T_0a1da_row6_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_0a1da_row1_col7,#T_0a1da_row8_col7,#T_0a1da_row11_col7,#T_0a1da_row13_col7,#T_0a1da_row15_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 50.0%, transparent 50.0%);
#         }#T_0a1da_row1_col8,#T_0a1da_row2_col8,#T_0a1da_row3_col8,#T_0a1da_row4_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 77.8%, transparent 77.8%);
#         }#T_0a1da_row2_col6,#T_0a1da_row5_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 70.0%, transparent 70.0%);
#         }#T_0a1da_row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 20.0%, transparent 20.0%);
#         }#T_0a1da_row3_col6,#T_0a1da_row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 60.0%, transparent 60.0%);
#         }#T_0a1da_row3_col7,#T_0a1da_row4_col7,#T_0a1da_row6_col7,#T_0a1da_row9_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 10.0%, transparent 10.0%);
#         }#T_0a1da_row5_col7,#T_0a1da_row7_col7,#T_0a1da_row17_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 30.0%, transparent 30.0%);
#         }#T_0a1da_row5_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 72.2%, transparent 72.2%);
#         }#T_0a1da_row6_col5,#T_0a1da_row7_col5,#T_0a1da_row8_col5,#T_0a1da_row10_col5,#T_0a1da_row12_col5,#T_0a1da_row13_col5,#T_0a1da_row14_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#0E28E8 33.3%, transparent 33.3%);
#         }#T_0a1da_row6_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 100.0%, transparent 100.0%);
#         }#T_0a1da_row7_col6,#T_0a1da_row8_col6,#T_0a1da_row12_col6,#T_0a1da_row14_col6,#T_0a1da_row16_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 40.0%, transparent 40.0%);
#         }#T_0a1da_row7_col8,#T_0a1da_row10_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 55.6%, transparent 55.6%);
#         }#T_0a1da_row8_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 44.4%, transparent 44.4%);
#         }#T_0a1da_row9_col3,#T_0a1da_row10_col3,#T_0a1da_row11_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#15C6DE 33.3%, transparent 33.3%);
#         }#T_0a1da_row9_col4,#T_0a1da_row12_col4,#T_0a1da_row13_col4,#T_0a1da_row14_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#F0EC10 100.0%, transparent 100.0%);
#         }#T_0a1da_row9_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 61.1%, transparent 61.1%);
#         }#T_0a1da_row10_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 50.0%, transparent 50.0%);
#         }#T_0a1da_row10_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 40.0%, transparent 40.0%);
#         }#T_0a1da_row11_col5,#T_0a1da_row15_col5,#T_0a1da_row16_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#0E28E8 66.7%, transparent 66.7%);
#         }#T_0a1da_row11_col8,#T_0a1da_row12_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 38.9%, transparent 38.9%);
#         }#T_0a1da_row12_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 60.0%, transparent 60.0%);
#         }#T_0a1da_row13_col6,#T_0a1da_row15_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 20.0%, transparent 20.0%);
#         }#T_0a1da_row13_col8,#T_0a1da_row15_col8,#T_0a1da_row17_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 33.3%, transparent 33.3%);
#         }#T_0a1da_row14_col7,#T_0a1da_row16_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 80.0%, transparent 80.0%);
#         }#T_0a1da_row14_col8,#T_0a1da_row16_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A 27.8%, transparent 27.8%);
#         }#T_0a1da_row17_col5,#T_0a1da_row18_col5,#T_0a1da_row19_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#0E28E8 100.0%, transparent 100.0%);
#         }#T_0a1da_row18_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 10.0%, transparent 10.0%);
#         }#T_0a1da_row18_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 100.0%, transparent 100.0%);
#         }#T_0a1da_row19_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 90.0%, transparent 90.0%);
#         }</style><table id="T_0a1da_" ><thead>    <tr>        <th class="col_heading level0 col0" >Position</th>        <th class="col_heading level0 col1" >Teams</th>        <th class="col_heading level0 col2" >Games_Played</th>        <th class="col_heading level0 col3" >Games_Won</th>        <th class="col_heading level0 col4" >Games_Drawn</th>        <th class="col_heading level0 col5" >Games_Lost</th>        <th class="col_heading level0 col6" >GF</th>

# %% [markdown]
# ## Further Reading
#
# - Eyal Trabelsi, 'https://towardsdatascience.com/style-pandas-dataframe-like-a-master-6b02bf6468b0', 2019
#
#
# - HTML Color Code: https://htmlcolorcodes.com/
#
#
# - https://pandas.pydata.org/pandas-docs/version/1.1.5/user_guide/style.html
#
#
# - https://www.datasciencelearner.com/styling-pandas-dataframe-like-a-master/
